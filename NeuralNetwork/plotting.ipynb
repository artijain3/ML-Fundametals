# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/Users/artijain/Documents/18-661_Intro_to_ML_Homeworks/homework6/hw6q3/data/SGD_0.1.csv")

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
ax1.set_title("Loss vs. Epoch")
ax1.plot(df['training_loss'], label='Training Loss')
ax1.plot(df['val_losses'], label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.set_title("Accuracy vs. Epoch")
ax2.plot(df['train_accuracies'], label='Training Accuracy')
ax2.plot(df['val_accuracies'], label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.tight_layout()  # Ensures subplots don't overlap
plt.show()

# %% [markdown]
# ## 3.4c

# %%
# !python main.py --save_stats --epochs 25 --lr 0.05
# Out:
# Starting epoch: 0
# Training Loop: 1843it [00:15, 122.57it/s]
# Testing Loop: 31it [00:00, 730.46it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:14, 126.48it/s]
# Testing Loop: 31it [00:00, 897.39it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:12, 148.95it/s]
# Testing Loop: 31it [00:00, 1025.20it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:14, 124.35it/s]
# Testing Loop: 31it [00:00, 699.26it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:12, 146.99it/s]
# Testing Loop: 31it [00:00, 1121.76it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:12, 148.54it/s]
# Testing Loop: 31it [00:00, 863.30it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:11, 153.66it/s]
# Testing Loop: 31it [00:00, 1327.91it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:12, 151.96it/s]
# Testing Loop: 31it [00:00, 743.83it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:12, 147.06it/s]
# Testing Loop: 31it [00:00, 919.25it/s]
# Starting epoch: 9
# ...

# %%
min([0.22711421337157348, 0.1496088128627554, 0.13095749502137669, 0.11096787126196538, 0.10944377322013835, 0.09502142198519295, 0.09057138474885411, 0.07199695273062208, 0.07801815184518686, 0.08442070753781213, 0.07408641610575804, 0.0797940700176352, 0.07356970282266258, 0.08044372996219867, 0.07645799192447589, 0.08066729954864714, 0.07514494307709677, 0.08223785034574227, 0.07594190477753629, 0.07328491352204576, 0.0665667457156103, 0.0739778084645604, 0.08340247722332807, 0.08082509594857332, 0.084465216461862])

# %%
# !python main.py --save_stats --epochs 25 --lr 0.1
# Out:
# Starting epoch: 0
# Training Loop: 1843it [00:11, 163.09it/s]
# Testing Loop: 31it [00:00, 932.56it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:11, 161.59it/s]
# Testing Loop: 31it [00:00, 806.92it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:12, 147.33it/s]
# Testing Loop: 31it [00:00, 1228.90it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:12, 148.49it/s]
# Testing Loop: 31it [00:00, 1024.99it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:13, 132.42it/s]
# Testing Loop: 31it [00:00, 613.13it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:12, 144.71it/s]
# Testing Loop: 31it [00:00, 611.92it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:13, 134.31it/s]
# Testing Loop: 31it [00:00, 664.69it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:13, 140.14it/s]
# Testing Loop: 31it [00:00, 1153.18it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:11, 166.42it/s]
# Testing Loop: 31it [00:00, 956.20it/s]
# Starting epoch: 9
# ...

# %%
min([0.15345293531706003, 0.101058239589723, 0.08445263942682589, 0.07231406988883675, 0.057327129519899385, 0.05630852802342637, 0.055503135339007956, 0.05550290165091051, 0.0611947986729923, 0.061053669283802, 0.0684836158408988, 0.06986585739324756, 0.05222506514061101, 0.05599061055096203, 0.0572490909581274, 0.05872579795605745, 0.05715116942166191, 0.06839384449648703, 0.06037236223066354, 0.059677098557911874, 0.05967598427878422, 0.061661666993226304, 0.06590904068026575, 0.060662269129738516, 0.06110881149141782])
# Out:
# 0.08278499778353866

# %%
# !python main.py --save_stats --epochs 25 --lr 0.2
# Out:
# Starting epoch: 0
# Training Loop: 1843it [00:11, 156.59it/s]
# Testing Loop: 31it [00:00, 739.08it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:13, 132.73it/s]
# Testing Loop: 31it [00:00, 1021.66it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:11, 156.48it/s]
# Testing Loop: 31it [00:00, 847.97it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:10, 169.90it/s]
# Testing Loop: 31it [00:00, 867.04it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:12, 149.64it/s]
# Testing Loop: 31it [00:00, 623.24it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:10, 169.87it/s]
# Testing Loop: 31it [00:00, 1099.22it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:11, 165.31it/s]
# Testing Loop: 31it [00:00, 1078.37it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:10, 169.79it/s]
# Testing Loop: 31it [00:00, 1408.57it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:10, 168.15it/s]
# Testing Loop: 31it [00:00, 1360.06it/s]
# Starting epoch: 9
# ...

# %%
min([0.15974411208467398, 0.11145042873803528, 0.10226015548202548, 0.09514964330881516, 0.1029294279154561, 0.09310007165640284, 0.11242661390274325, 0.11557671822404093, 0.10388083499761178, 0.1293223380759763, 0.12122949010898468, 0.13594312972451122, 0.11517251035459453, 0.13901882619857242, 0.12677174000327238, 0.08409877151903898, 0.10934472879971315, 0.12136907108467002, 0.11491757314211784, 0.11465852516049559, 0.11867962639044445, 0.11810388245530683, 0.11963388574761923, 0.110209040073269, 0.11933154945700537])
# Out:
# 0.11704339269371812

# %%
# !python main.py --save_stats --epochs 25 --lr 0.5
# Out:
# Starting epoch: 0
# Training Loop: 11it [00:00, 106.00it/s]/Users/artijain/Documents/18-661_Intro_to_ML_Homeworks/homework6/hw6q3/npnn/modules.py:90: RuntimeWarning: overflow encountered in exp
#   elu_output[row] = np.where(x[row] > 0, x[row], self.alpha*(np.exp(x[row])-1))
# /Users/artijain/Documents/18-661_Intro_to_ML_Homeworks/homework6/hw6q3/npnn/modules.py:122: RuntimeWarning: overflow encountered in exp
#   temp = np.diag(np.where(self.x[row] > 0, 1, self.alpha * (np.exp(self.x[row])))) # 1 x dim
# Training Loop: 1843it [00:10, 168.87it/s]
# Testing Loop: 31it [00:00, 1504.95it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:11, 166.83it/s]
# Testing Loop: 31it [00:00, 1429.49it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:11, 158.71it/s]
# Testing Loop: 31it [00:00, 947.52it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:15, 119.75it/s]
# Testing Loop: 31it [00:00, 553.54it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:13, 137.62it/s]
# ...

# %%
min([21.076081294735424, 21.052869751459173, 21.052869751459173, 21.12250438128793, 21.076081294735424, 21.076081294735427, 21.099292838011674, 21.076081294735424, 21.05286975145917, 21.076081294735427, 21.12250438128793, 21.09929283801167, 21.099292838011678, 21.076081294735424, 21.052869751459177, 21.052869751459173, 21.05286975145917, 21.076081294735424, 21.099292838011678, 21.052869751459173, 21.07608129473542, 21.099292838011674, 21.076081294735427, 21.052869751459177, 21.076081294735427])
# Out:
# 20.68148505903916

# %%
# !python main.py --save_stats --epochs 25 --lr 1
# Out:
# Starting epoch: 0
# Training Loop: 0it [00:00, ?it/s]/Users/artijain/Documents/18-661_Intro_to_ML_Homeworks/homework6/hw6q3/npnn/modules.py:90: RuntimeWarning: overflow encountered in exp
#   elu_output[row] = np.where(x[row] > 0, x[row], self.alpha*(np.exp(x[row])-1))
# /Users/artijain/Documents/18-661_Intro_to_ML_Homeworks/homework6/hw6q3/npnn/modules.py:122: RuntimeWarning: overflow encountered in exp
#   temp = np.diag(np.where(self.x[row] > 0, 1, self.alpha * (np.exp(self.x[row])))) # 1 x dim
# Training Loop: 1843it [00:12, 142.75it/s]
# Testing Loop: 31it [00:00, 633.85it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:13, 137.27it/s]
# Testing Loop: 31it [00:00, 902.71it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:12, 145.78it/s]
# Testing Loop: 31it [00:00, 1285.99it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:10, 170.48it/s]
# Testing Loop: 31it [00:00, 1174.68it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:11, 167.21it/s]
# ...

# %%
min([20.983235121630422, 21.029658208182923, 20.983235121630422, 20.983235121630422, 21.006446664906672, 20.983235121630425, 20.983235121630425, 21.029658208182926, 21.006446664906676, 20.983235121630422, 20.983235121630425, 20.98323512163042, 20.983235121630425, 21.006446664906672, 21.00644666490667, 20.983235121630415, 20.983235121630422, 21.00644666490667, 20.983235121630422, 21.029658208182923, 20.983235121630422, 21.006446664906676, 20.983235121630425, 21.006446664906672, 20.983235121630422])
# Out:
# 20.983235121630415

# %%
lr_min_loss = {
    0.05: 0.0665667457156103,
    0.1: 0.05222506514061101,
    0.2: 0.08409877151903898,
    0.5: 21.05286975145917,
    1: 20.983235121630415
}

lr_values = list(lr_min_loss.keys())
loss_values = list(lr_min_loss.values())

# %%
plt.figure(figsize=(10, 4))
plt.plot(lr_values, loss_values, marker='o')
# plt.xscale('log')
plt.yscale('log')
plt.xlabel('Learning Rate')
plt.ylabel('Minimum Validation Loss')

# Set the title
plt.title('Minimum Validation Loss vs. Learning Rate')
plt.xticks(lr_values)
# Show the plot
plt.show()

# %% [markdown]
# ## 3.5

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.015 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:13, 133.22it/s]
# Testing Loop: 31it [00:00, 1019.81it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:13, 133.35it/s]
# Testing Loop: 31it [00:00, 1283.92it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:13, 138.64it/s]
# Testing Loop: 31it [00:00, 1323.14it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:16, 109.85it/s]
# Testing Loop: 31it [00:00, 896.00it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:17, 106.74it/s]
# Testing Loop: 31it [00:00, 1136.29it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:12, 145.56it/s]
# Testing Loop: 31it [00:00, 1146.63it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:12, 148.59it/s]
# Testing Loop: 31it [00:00, 1240.10it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:12, 148.86it/s]
# Testing Loop: 31it [00:00, 1470.32it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:11, 157.68it/s]
# Testing Loop: 31it [00:00, 1189.11it/s]
# Starting epoch: 9
# ...

# %%
min([0.13272122191471797, 0.0916982125929004, 0.08383750207083081, 0.1307372351380487, 0.12241921266920841, 0.10292921222356456, 0.1151833437587455, 0.11902224673332346, 0.14344735138287992, 0.12813964437579833, 0.1341521729079, 0.09577822427053918, 0.1520239592285589, 0.1894646097475562, 0.1565923642568073, 0.151129831064878, 0.2026405432357379, 0.1580093068995229, 0.14810684559340598, 0.1352708270890958, 0.16796842569402767, 0.14033601556621836, 0.2057008223293624, 0.17773541073398205, 0.17530787200602524])
# Out:
# 0.08383750207083081

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.003 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:14, 126.71it/s]
# Testing Loop: 31it [00:00, 1115.14it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:14, 123.02it/s]
# Testing Loop: 31it [00:00, 1134.13it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:13, 138.20it/s]
# Testing Loop: 31it [00:00, 1032.37it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:14, 128.31it/s]
# Testing Loop: 31it [00:00, 822.22it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:15, 121.32it/s]
# Testing Loop: 31it [00:00, 696.25it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:18, 101.32it/s]
# Testing Loop: 31it [00:00, 989.83it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:16, 113.92it/s]
# Testing Loop: 31it [00:00, 1089.17it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:12, 142.53it/s]
# Testing Loop: 31it [00:00, 680.07it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:12, 145.71it/s]
# Testing Loop: 31it [00:00, 1333.57it/s]
# Starting epoch: 9
# ...

# %%
min([0.09097780606508173, 0.04940834556648323, 0.06817931845711883, 0.06383590416994758, 0.06305907204734429, 0.06093061647001314, 0.054364742642601334, 0.06342744637287943, 0.05138614582618638, 0.05331882647541203, 0.08023984715061984, 0.16877762452689177, 0.0774076251411903, 0.10249519029606582, 0.10569923886840261, 0.10826899576867473, 0.04832325661095596, 0.04113488766147786, 0.11758635018336677, 0.0961526500413949, 0.1283808223806521, 0.08530559558361221, 0.07103253689595126, 0.0994777571980873, 0.07211779666403513])
# Out:
# 0.04113488766147786

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.025 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:15, 119.76it/s]
# Testing Loop: 31it [00:00, 1223.57it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:12, 151.11it/s]
# Testing Loop: 31it [00:00, 735.07it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:13, 135.45it/s]
# Testing Loop: 31it [00:00, 1094.63it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:14, 125.55it/s]
# Testing Loop: 31it [00:00, 433.26it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:15, 121.62it/s]
# Testing Loop: 31it [00:00, 460.65it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:16, 110.84it/s]
# Testing Loop: 31it [00:00, 795.44it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:15, 117.39it/s]
# Testing Loop: 31it [00:00, 1378.02it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:13, 137.91it/s]
# Testing Loop: 31it [00:00, 1247.24it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:12, 150.68it/s]
# Testing Loop: 31it [00:00, 1495.69it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.001 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:13, 139.50it/s]
# Testing Loop: 31it [00:00, 1048.68it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:12, 144.08it/s]
# Testing Loop: 31it [00:00, 1151.60it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:12, 145.53it/s]
# Testing Loop: 31it [00:00, 1331.03it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:12, 147.04it/s]
# Testing Loop: 31it [00:00, 1264.99it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:12, 142.26it/s]
# Testing Loop: 31it [00:00, 1234.13it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:12, 146.70it/s]
# Testing Loop: 31it [00:00, 1026.19it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:12, 147.36it/s]
# Testing Loop: 31it [00:00, 1130.03it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:12, 145.31it/s]
# Testing Loop: 31it [00:00, 1137.28it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:12, 147.56it/s]
# Testing Loop: 31it [00:00, 876.58it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.0035 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:15, 119.80it/s]
# Testing Loop: 31it [00:00, 658.90it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:14, 123.97it/s]
# Testing Loop: 31it [00:00, 856.63it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:14, 127.07it/s]
# Testing Loop: 31it [00:00, 763.49it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:17, 105.87it/s]
# Testing Loop: 31it [00:00, 1127.02it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:18, 100.89it/s]
# Testing Loop: 31it [00:00, 1563.98it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:19, 94.58it/s]
# Testing Loop: 31it [00:00, 529.28it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:17, 104.33it/s]
# Testing Loop: 31it [00:00, 835.45it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:18, 97.85it/s]
# Testing Loop: 31it [00:00, 779.80it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:17, 102.77it/s]
# Testing Loop: 31it [00:00, 874.90it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.01 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:15, 120.58it/s]
# Testing Loop: 31it [00:00, 859.78it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:16, 111.21it/s]
# Testing Loop: 31it [00:00, 1239.27it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:14, 123.74it/s]
# Testing Loop: 31it [00:00, 1304.33it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:13, 132.60it/s]
# Testing Loop: 31it [00:00, 562.44it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:14, 125.40it/s]
# Testing Loop: 31it [00:00, 388.13it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:18, 98.65it/s]
# Testing Loop: 31it [00:00, 1128.83it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:14, 125.66it/s]
# Testing Loop: 31it [00:00, 910.66it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:15, 121.76it/s]
# Testing Loop: 31it [00:00, 841.38it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:16, 111.30it/s]
# Testing Loop: 31it [00:00, 812.35it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.0005 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:12, 151.03it/s]
# Testing Loop: 31it [00:00, 1175.13it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:11, 153.71it/s]
# Testing Loop: 31it [00:00, 805.91it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:12, 152.63it/s]
# Testing Loop: 31it [00:00, 1020.78it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:12, 144.83it/s]
# Testing Loop: 31it [00:00, 742.88it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:13, 139.08it/s]
# Testing Loop: 31it [00:00, 1535.79it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:12, 153.06it/s]
# Testing Loop: 31it [00:00, 1464.89it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:13, 138.05it/s]
# Testing Loop: 31it [00:00, 912.78it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:16, 109.10it/s]
# Testing Loop: 31it [00:00, 672.61it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:16, 108.43it/s]
# Testing Loop: 31it [00:00, 1269.24it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.0025 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:17, 103.13it/s]
# Testing Loop: 31it [00:00, 1322.69it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:14, 127.05it/s]
# Testing Loop: 31it [00:00, 981.38it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:13, 135.20it/s]
# Testing Loop: 31it [00:00, 1018.19it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:13, 136.27it/s]
# Testing Loop: 31it [00:00, 1052.56it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:13, 132.45it/s]
# Testing Loop: 31it [00:00, 871.16it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:13, 133.58it/s]
# Testing Loop: 31it [00:00, 1085.09it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:13, 134.39it/s]
# Testing Loop: 31it [00:00, 1175.38it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:13, 135.18it/s]
# Testing Loop: 31it [00:00, 1242.19it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:13, 134.37it/s]
# Testing Loop: 31it [00:00, 820.48it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.06 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:14, 129.33it/s]
# Testing Loop: 31it [00:00, 996.78it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:13, 136.74it/s]
# Testing Loop: 31it [00:00, 1136.99it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:15, 120.94it/s]
# Testing Loop: 31it [00:00, 787.00it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:13, 140.14it/s]
# Testing Loop: 31it [00:00, 975.00it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:13, 137.58it/s]
# Testing Loop: 31it [00:00, 940.50it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:14, 128.15it/s]
# Testing Loop: 31it [00:00, 872.78it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:15, 121.57it/s]
# Testing Loop: 31it [00:00, 926.04it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:13, 136.16it/s]
# Testing Loop: 31it [00:00, 1383.45it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:13, 132.04it/s]
# Testing Loop: 31it [00:00, 979.31it/s]
# Starting epoch: 9
# ...

# %% [markdown]
# ## heree

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.04 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:12, 143.18it/s]
# Testing Loop: 31it [00:00, 1199.61it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:13, 134.76it/s]
# Testing Loop: 31it [00:00, 1191.72it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:17, 102.45it/s]
# Testing Loop: 31it [00:00, 971.63it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:15, 116.20it/s]
# Testing Loop: 31it [00:00, 737.47it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:14, 125.04it/s]
# Testing Loop: 31it [00:00, 729.21it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:17, 105.22it/s]
# Testing Loop: 31it [00:00, 670.17it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:14, 129.12it/s]
# Testing Loop: 31it [00:00, 797.10it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:16, 114.92it/s]
# Testing Loop: 31it [00:00, 531.25it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:15, 120.75it/s]
# Testing Loop: 31it [00:00, 1148.62it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.005 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:13, 132.76it/s]
# Testing Loop: 31it [00:00, 1076.84it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:13, 137.56it/s]
# Testing Loop: 31it [00:00, 1033.75it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:13, 136.31it/s]
# Testing Loop: 31it [00:00, 942.20it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:13, 140.89it/s]
# Testing Loop: 31it [00:00, 1019.54it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:13, 137.88it/s]
# Testing Loop: 31it [00:00, 1184.93it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:13, 138.02it/s]
# Testing Loop: 31it [00:00, 957.62it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:13, 139.14it/s]
# Testing Loop: 31it [00:00, 1411.66it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:13, 136.92it/s]
# Testing Loop: 31it [00:00, 857.49it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:13, 135.77it/s]
# Testing Loop: 31it [00:00, 1128.51it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.08 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:16, 111.08it/s]
# Testing Loop: 31it [00:00, 546.85it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:16, 113.45it/s]
# Testing Loop: 31it [00:00, 701.75it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:14, 125.87it/s]
# Testing Loop: 31it [00:00, 903.89it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:14, 124.70it/s]
# Testing Loop: 31it [00:00, 1030.68it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:15, 122.84it/s]
# Testing Loop: 31it [00:00, 912.89it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:19, 93.65it/s]
# Testing Loop: 31it [00:00, 802.50it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:23, 79.11it/s]
# Testing Loop: 31it [00:00, 540.68it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:20, 91.69it/s]
# Testing Loop: 31it [00:00, 884.05it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:20, 91.05it/s]
# Testing Loop: 31it [00:00, 767.50it/s]
# Starting epoch: 9
# ...

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.1 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1843it [00:14, 125.03it/s]
# Testing Loop: 31it [00:00, 944.48it/s]
# Starting epoch: 1
# Training Loop: 1843it [00:14, 122.92it/s]
# Testing Loop: 31it [00:00, 1019.30it/s]
# Starting epoch: 2
# Training Loop: 1843it [00:14, 129.90it/s]
# Testing Loop: 31it [00:00, 1275.83it/s]
# Starting epoch: 3
# Training Loop: 1843it [00:12, 142.33it/s]
# Testing Loop: 31it [00:00, 412.78it/s]
# Starting epoch: 4
# Training Loop: 1843it [00:13, 141.26it/s]
# Testing Loop: 31it [00:00, 1402.66it/s]
# Starting epoch: 5
# Training Loop: 1843it [00:12, 144.42it/s]
# Testing Loop: 31it [00:00, 802.34it/s]
# Starting epoch: 6
# Training Loop: 1843it [00:12, 144.74it/s]
# Testing Loop: 31it [00:00, 1350.58it/s]
# Starting epoch: 7
# Training Loop: 1843it [00:12, 143.75it/s]
# Testing Loop: 31it [00:00, 1325.28it/s]
# Starting epoch: 8
# Training Loop: 1843it [00:12, 146.63it/s]
# Testing Loop: 31it [00:00, 1229.72it/s]
# Starting epoch: 9
# ...

# %% [markdown]
# #### Getting the min val loss values

# %%
lr_adam_values = {
    0.0005: 0.08567271810914086,
    0.001: 0.10404327440454604,
    0.0025: 0.08443270432695534,
    0.003: 0.04113488766147786,
    0.0035: 0.08741940570521389,
    0.005: 0.09432093088691057,
    0.01: 0.09798446636637674,
    0.015: 0.08383750207083081,
    0.025: 0.07377966514585553,
    0.04: 0.11198091319303084,
    0.06: 0.0717108160097982,
    0.08: 0.059736166251123275,
    0.1: 0.09689781480427699
}

lr_values = list(lr_adam_values.keys())
loss_values = list(lr_adam_values.values())

# %%
lr_adam_values = {
    0.001: 0.10404327440454604,
    0.0025: 0.08443270432695534,
    0.003: 0.04113488766147786,
    0.0035: 0.08741940570521389,
    0.005: 0.09432093088691057,
    0.01: 0.09798446636637674,
    0.015: 0.08383750207083081,
    0.025: 0.07377966514585553,
    0.04: 0.11198091319303084,
    0.06: 0.0717108160097982,
    0.08: 0.059736166251123275,
    0.1: 0.09689781480427699
}

# %%
plt.figure(figsize=(10, 4))
plt.plot(lr_values, loss_values, marker='o')
plt.xscale('log')
# plt.yscale('log')
plt.xlabel('Learning Rate')
plt.ylabel('Minimum Validation Loss')

# Set the title
plt.title('Minimum Validation Loss vs. Learning Rate for Adam')
plt.xticks(lr_values)
# Show the plot
plt.show()

# %% [markdown]
# ## rerunning

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.001 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:16, 96.80it/s]
# Testing Loop: 312it [00:00, 838.12it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:16, 92.63it/s]
# Testing Loop: 312it [00:00, 857.48it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:13, 115.02it/s]
# Testing Loop: 312it [00:00, 873.79it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:15, 99.64it/s]
# Testing Loop: 312it [00:00, 948.29it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:13, 117.98it/s]
# Testing Loop: 312it [00:00, 937.24it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:13, 114.16it/s]
# Testing Loop: 312it [00:00, 887.89it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:13, 116.90it/s]
# Testing Loop: 312it [00:00, 809.89it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:16, 96.37it/s]
# Testing Loop: 312it [00:00, 730.54it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:14, 109.44it/s]
# Testing Loop: 312it [00:00, 901.53it/s]
# Starting epoch: 9
# ...

# %%
min([0.13629479303417208, 0.11160339087382048, 0.1018171248213083, 0.11133252815783688, 0.10242775877341859, 0.1348296723572009, 0.11158608449085541, 0.12581605803409707, 0.10461798901016306, 0.1502694951705805, 0.1288517162125238, 0.142577207947376, 0.12875174835335929, 0.15428170190326485, 0.15803356345003636, 0.15308426203179357, 0.169452417016909, 0.16648899230475955, 0.15579454653972455, 0.1726480985568742, 0.1654496331188706, 0.17847658095051108, 0.2185706975558829, 0.20992277557903685, 0.16916014744635255])
# Out:
# 0.1018171248213083

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.0015 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:14, 105.85it/s]
# Testing Loop: 312it [00:00, 884.87it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:13, 116.22it/s]
# Testing Loop: 312it [00:00, 831.87it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:13, 113.99it/s]
# Testing Loop: 312it [00:00, 1025.95it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:13, 116.37it/s]
# Testing Loop: 312it [00:00, 883.79it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:14, 108.48it/s]
# Testing Loop: 312it [00:00, 777.80it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:13, 117.21it/s]
# Testing Loop: 312it [00:00, 715.15it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:14, 109.39it/s]
# Testing Loop: 312it [00:00, 928.21it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:15, 98.39it/s]
# Testing Loop: 312it [00:00, 686.36it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:16, 96.78it/s]
# Testing Loop: 312it [00:00, 926.03it/s]
# Starting epoch: 9
# ...

# %%
min([0.16451850232091766, 0.11026676159832045, 0.12251805470159301, 0.0888644709513682, 0.0995660873064705, 0.11594483971738985, 0.1321205238681623, 0.11580473400076102, 0.11932870965977323, 0.13598966422225586, 0.15566601222807736, 0.1369460135290354, 0.15137815950751266, 0.14706151178711435, 0.16445237508926613, 0.14808462016682356, 0.1752655949488474, 0.15706284451056, 0.16339041171439192, 0.166058438524522, 0.1813393521839999, 0.1733612324952918, 0.1923635085294331, 0.15855373723912158, 0.20255155413839104])
# Out:
# 0.0888644709513682

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.002 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:14, 104.91it/s]
# Testing Loop: 312it [00:00, 947.30it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:14, 110.34it/s]
# Testing Loop: 312it [00:00, 862.01it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:15, 102.52it/s]
# Testing Loop: 312it [00:00, 426.36it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:14, 109.27it/s]
# Testing Loop: 312it [00:00, 754.95it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:14, 107.71it/s]
# Testing Loop: 312it [00:00, 882.95it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:15, 98.29it/s]
# Testing Loop: 312it [00:00, 575.42it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:19, 79.46it/s]
# Testing Loop: 312it [00:00, 467.57it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:19, 81.31it/s]
# Testing Loop: 312it [00:00, 722.35it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:22, 70.14it/s]
# Testing Loop: 312it [00:00, 636.95it/s]
# Starting epoch: 9
# ...

# %%
min([0.1544401352919765, 0.14427237367413032, 0.10358419934515542, 0.10783505569747448, 0.11799833094116942, 0.10942659843332095, 0.12469122311251223, 0.15600598539937044, 0.14345095577733216, 0.18313436688985307, 0.17537632162629982, 0.15327762815688745, 0.1786918679812065, 0.15802325953627247, 0.20420340806233503, 0.2138011029054488, 0.20775630727224717, 0.18227683149301618, 0.16698498268734097, 0.19909239151810207, 0.210151890025038, 0.2005072074207113, 0.20644715690007664, 0.2018902204393955, 0.19533158977100007])
# Out:
# 0.10358419934515542

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.0025 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:16, 97.23it/s]
# Testing Loop: 312it [00:00, 881.96it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:13, 118.74it/s]
# Testing Loop: 312it [00:00, 1054.93it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:13, 115.43it/s]
# Testing Loop: 312it [00:00, 872.44it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:13, 119.45it/s]
# Testing Loop: 312it [00:00, 935.95it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:13, 119.40it/s]
# Testing Loop: 312it [00:00, 776.69it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:15, 99.77it/s]
# Testing Loop: 312it [00:00, 801.02it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:14, 105.29it/s]
# Testing Loop: 312it [00:00, 416.90it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:15, 97.67it/s]
# Testing Loop: 312it [00:00, 580.38it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:16, 93.85it/s]
# Testing Loop: 312it [00:00, 753.91it/s]
# Starting epoch: 9
# ...

# %%
min([0.16851733743865735, 0.13382981422939116, 0.1121697530275619, 0.12439722967209058, 0.09909468953951031, 0.09790415935493024, 0.10967460509505869, 0.13091270946806452, 0.14426869666354233, 0.13386334014159817, 0.13003097234543076, 0.12412231471553699, 0.13066982793007023, 0.13247442588696745, 0.17342101154872167, 0.15841487364501264, 0.1671162695635718, 0.16636911603335058, 0.1699753286919652, 0.18263434016454055, 0.1696869914124205, 0.19832529832691964, 0.1932133803594313, 0.21024451222048682, 0.18227015077727038])
# Out:
# 0.09790415935493024

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.005 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:15, 97.79it/s]
# Testing Loop: 312it [00:00, 697.26it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:12, 127.03it/s]
# Testing Loop: 312it [00:00, 1115.21it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:16, 96.83it/s]
# Testing Loop: 312it [00:00, 759.54it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:17, 91.23it/s]
# Testing Loop: 312it [00:00, 433.71it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:15, 103.34it/s]
# Testing Loop: 312it [00:00, 670.29it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:12, 129.42it/s]
# Testing Loop: 312it [00:00, 633.88it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:15, 98.10it/s]
# Testing Loop: 312it [00:00, 671.57it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:16, 94.12it/s]
# Testing Loop: 312it [00:00, 717.63it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:16, 95.51it/s]
# Testing Loop: 312it [00:00, 624.88it/s]
# Starting epoch: 9
# ...

# %%
min([0.14290276101640545, 0.10522359162952082, 0.09948198547541448, 0.11316342137744144, 0.09747328039292319, 0.09702491085439323, 0.11378360987003003, 0.12208913258371099, 0.11617582803493583, 0.1209666998826008, 0.12814568400152998, 0.16170949598708917, 0.1482785191622597, 0.16792206141276217, 0.16640351820120464, 0.1511560759032396, 0.15839135033876509, 0.15252715467346187, 0.16710145780610575, 0.21205021139533528, 0.18055238348699199, 0.16756825868422018, 0.20123085977446714, 0.17671413221076754, 0.18761734922180054])
# Out:
# 0.09702491085439323

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.01 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:20, 77.53it/s]
# Testing Loop: 312it [00:00, 761.93it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:19, 81.03it/s]
# Testing Loop: 312it [00:00, 449.79it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:19, 79.27it/s]
# Testing Loop: 312it [00:00, 828.39it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:14, 111.39it/s]
# Testing Loop: 312it [00:00, 766.12it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:16, 93.39it/s]
# Testing Loop: 312it [00:00, 771.65it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:14, 109.67it/s]
# Testing Loop: 312it [00:00, 899.70it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:13, 111.97it/s]
# Testing Loop: 312it [00:00, 967.18it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:13, 119.15it/s]
# Testing Loop: 312it [00:00, 1120.71it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:12, 125.44it/s]
# Testing Loop: 312it [00:00, 942.56it/s]
# Starting epoch: 9
# ...

# %%
min([0.13850671170690018, 0.0986299611831664, 0.10640812855850229, 0.10224708809925978, 0.0964497115727638, 0.12214492750597818, 0.16963235416092923, 0.11565252959441476, 0.11934826483865785, 0.13136452677014426, 0.13218263731534421, 0.15534668664776682, 0.17944938339602473, 0.156744884664205, 0.13636900505624558, 0.14660617442648916, 0.16481848997229034, 0.15507638761995368, 0.16173760958964387, 0.16843477380071256, 0.18452968513591947, 0.1623780172367969, 0.20044880727128828, 0.19080726893294453, 0.19538960627343194])
# Out:
# 0.0964497115727638

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 0.5 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:15, 99.77it/s]
# Testing Loop: 312it [00:00, 743.26it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:13, 115.66it/s]
# Testing Loop: 312it [00:00, 956.09it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:14, 106.76it/s]
# Testing Loop: 312it [00:00, 947.23it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:13, 119.40it/s]
# Testing Loop: 312it [00:00, 944.58it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:13, 118.70it/s]
# Testing Loop: 312it [00:00, 729.36it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:14, 110.44it/s]
# Testing Loop: 312it [00:00, 849.41it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:13, 112.84it/s]
# Testing Loop: 312it [00:00, 865.26it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:14, 106.73it/s]
# Testing Loop: 312it [00:00, 854.99it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:12, 122.87it/s]
# Testing Loop: 312it [00:00, 924.23it/s]
# Starting epoch: 9
# ...

# %%
min([0.1363304215121181, 0.12080611045806935, 0.12271363582879087, 0.1089200118683701, 0.1256791488187315, 0.11761522432340317, 0.11959165856360442, 0.1252190570525056, 0.12485863540809078, 0.13971955485322327, 0.14665068362164213, 0.151658308560598, 0.1965009265882705, 0.19239833415018928, 0.1902609623545648, 0.20552382759577198, 0.16216153361764893, 0.16396586407700317, 0.15821516278728934, 0.16443906292850521, 0.18759678573743555, 0.1905584400195161, 0.22341546220749914, 0.18837424292348892, 0.22062892728069672])
# Out:
# 0.1089200118683701

# %%
# !python main.py --save_pred --save_stats --epochs 25 --lr 1 --opt ADAM
# Out:
# yo
# Starting epoch: 0
# Training Loop: 1562it [00:14, 106.55it/s]
# Testing Loop: 312it [00:00, 581.54it/s]
# Starting epoch: 1
# Training Loop: 1562it [00:16, 95.24it/s]
# Testing Loop: 312it [00:00, 705.52it/s]
# Starting epoch: 2
# Training Loop: 1562it [00:13, 114.31it/s]
# Testing Loop: 312it [00:00, 1146.78it/s]
# Starting epoch: 3
# Training Loop: 1562it [00:10, 145.07it/s]
# Testing Loop: 312it [00:00, 1200.00it/s]
# Starting epoch: 4
# Training Loop: 1562it [00:11, 140.31it/s]
# Testing Loop: 312it [00:00, 1210.79it/s]
# Starting epoch: 5
# Training Loop: 1562it [00:11, 131.46it/s]
# Testing Loop: 312it [00:00, 978.94it/s]
# Starting epoch: 6
# Training Loop: 1562it [00:10, 146.20it/s]
# Testing Loop: 312it [00:00, 1076.96it/s]
# Starting epoch: 7
# Training Loop: 1562it [00:10, 144.74it/s]
# Testing Loop: 312it [00:00, 1037.86it/s]
# Starting epoch: 8
# Training Loop: 1562it [00:11, 137.70it/s]
# Testing Loop: 312it [00:00, 1007.79it/s]
# Starting epoch: 9
# ...

# %%
min([0.1404967631107755, 0.09310019613247225, 0.10082972079672795, 0.10024738772662607, 0.10196010840060865, 0.10850248416554442, 0.09577031738520088, 0.104088177140334, 0.10790453376937528, 0.13222114986737415, 0.12901368801952048, 0.1217354911266696, 0.1447366624788407, 0.1290586218405136, 0.16426302464736167, 0.13530275300760786, 0.16024740572253168, 0.1849404994520283, 0.1435327376037816, 0.189114525426998, 0.20550979105846987, 0.1987782408450215, 0.18056603036480792, 0.1923362648833011, 0.22363198825204678])
# Out:
# 0.09310019613247225

# %%
lr_adam_values = {
    0.001: 0.10181712482130833,
    0.0015: 0.0888644709513682,
    0.002: 0.10358419934515542,
    0.0025: 0.09790415935493024,
    0.005: 0.09702491085439323,
    0.01: 0.0964497115727638,
    0.5: 0.1089200118683701,
}

lr_values = list(lr_adam_values.keys())
loss_values = list(lr_adam_values.values())

# %%
plt.figure(figsize=(10, 4))
plt.plot(lr_values, loss_values, marker='o')
plt.xscale('log')
# plt.yscale('log')
plt.xlabel('Learning Rate')
plt.ylabel('Minimum Validation Loss')

# Set the title
plt.title('Minimum Validation Loss vs. Learning Rate for Adam')
plt.xticks(lr_values)
# Show the plot
plt.show()

# %%
df = pd.read_csv("/Users/artijain/Documents/18-661_Intro_to_ML_Homeworks/homework6/hw6q3/data/ADAM_0.005.csv")

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
ax1.set_title("Loss vs. Epoch")
ax1.plot(df['training_loss'], label='Training Loss')
ax1.plot(df['val_losses'], label='Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.set_title("Accuracy vs. Epoch")
ax2.plot(df['train_accuracies'], label='Training Accuracy')
ax2.plot(df['val_accuracies'], label='Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.tight_layout()  # Ensures subplots don't overlap
plt.show()
